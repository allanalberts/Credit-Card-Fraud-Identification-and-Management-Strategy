# %% [markdown]
# # Capstone 2 - Final Run Though - Version 3

# %%
import sys
sys.path.insert(0, '../src')
import helpers as h
import score_metrics as sm
import score_costs as sc
import eda_plots as ep
import smote_tuning as st
import feature_engineering as ef

#import pickle
import matplotlib.pyplot as plt

SEED = 123
CPU = -1
holdoutseed = 4
FOLDS = 5

FraudBudget=0.0005
ReviewCost=10
ChargebackFee=20

# %%
# Load data
X_train, X_test, \
y_train, y_test, \
c_train, c_test, \
X_holdout, y_holdout, c_holdout, \
features = h.load_data(4, engineered_features=False)

# %%
# # Initilization of classifiers
# classifiers = h.initialize_classifier_dict()
# clf_lst = [clf for clf in classifiers]

# %%
# # Run CV on default parameter classifiers
# classifiers = sm.cvtrain_classifiers(clf_lst, classifiers, X_train, y_train)
# classifiers = sm.fit_classifiers(clf_lst, classifiers, X_train, y_train)
# classifiers = sm.score_classifiers(clf_lst, classifiers, X_test, y_test)

# %%
# Save Version
# h.save_classifier_dict(classifiers, "20")

# load from save classifiers version
classifiers = h.load_classifier_dict("classifiers_ver20.pickle")
clf_lst = [clf for clf in classifiers]

# %%
# plot default parameter classifier performance
fig = sm.plot_all_metrics(clf_lst, classifiers)
fig.savefig("../images/default_clf_scores.png")

# %%
# show the dollar costs for default model
cost_matrix = sc.partial_review(c_test, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_test, y_test, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)

# %%
# show the cost% for default model
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_test, y_test)

# %%
# Add smote analysis - skip the cv for now since have the plot
classifiers = st.add_smote_classifiers_to_dict(clf_lst, classifiers)
classifiers['LR_smote']['SMOTE_bestparm'] = 0.2
classifiers['RF_smote']['SMOTE_bestparm'] = 0.04
classifiers['XGB_smote']['SMOTE_bestparm'] = 0.15

# %%
# Save Version
# h.save_classifier_dict(classifiers, "21")

# load from save classifiers version
classifiers = h.load_classifier_dict("classifiers_ver21.pickle")
clf_lst = ['LR_smote','RF_smote','XGB_smote']

# %%
# Fit the training data with smote and run the full metrics
# clf_lst = ['LR_smote','RF_smote','XGB_smote']
# classifiers = st.update_pipeline(clf_lst, classifiers)
# classifiers = sm.fit_classifiers(clf_lst, classifiers, X_train, y_train, SMOTE=True, TimeIt=True)

# %%
classifiers = sm.score_classifiers(clf_lst, classifiers, X_test, y_test)

# %%
fig, ax = plt.subplots()
sm.plot_clf_metrics(ax, clf_lst, classifiers, score_type="test")

# %%
# show the dollar costs for SMOTE upsampled model
cost_matrix = sc.partial_review(c_test, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_test, y_test, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)

# %%
# show the cost% for SMOTE upsampled model
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_test, y_test)

# %%
# add the ensemble
classifiers = sm.create_voting_classifier(clf_lst, classifiers, X_train, y_train)
# Out:
# 128 seconds cross_validate execution time for Voting classifier
# {'RF': {'clf_desc': 'RandomForest',
#   'model': RandomForestClassifier(n_jobs=-1, random_state=123),
#   'c': 'g',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe5898ac950>,
#   'threshold': 0.5,
#   'pipeline': Pipeline(steps=[('Classifier',
#                    RandomForestClassifier(n_jobs=-1, random_state=123))]),
#   'cv_Recall_scores': array([0.9047619 , 0.82539683, 0.74603175, 0.73015873, 0.66666667]),
#   'cv_Precision_scores': array([0.9047619 , 1.        , 0.97916667, 0.86792453, 0.93333333]),
#   'cv_f1_scores': array([0.9047619 , 0.90434783, 0.84684685, 0.79310345, 0.77777778]),
#   'cvAvg_Recall_score': 0.7746031746031746,
#   'cvAvg_Precision_score': 0.9370372866127583,
#   'cvAvg_f1_score': 0.8453675607498697,
#   'fitted_model': RandomForestClassifier(n_jobs=-1, random_state=123),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.7848101265822784,
#   'test_Precision_score': 0.9393939393939394,
#   'test_f1_score': 0.8551724137931035,
#   'pred_prob': array([0., 0., 0., ..., 0., 0., 0.]),
#   'cnf_matrix': array([[45485,     5],
#          [   17,    62]]),
#   'cs_cnf_matrix': array([[   0.  ,   30.5 ],
#          [2294.23,  310.  ]]),
#   'TotalCosts': 2634.7299999999996},
#  'XGB': {'clf_desc': 'XGBoost',
#   'model': XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                 importance_type='gain', interaction_constraints='',
#                 learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#                 random_state=123, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                 subsample=1, tree_method='exact', validate_parameters=1,
#                 verbosity=None),
#   'c': 'blue',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe585426590>,
#   'threshold': 0.5,
#   'pipeline': Pipeline(steps=[('Classifier',
#                    XGBClassifier(base_score=0.5, booster='gbtree',
#                                  colsample_bylevel=1, colsample_bynode=1,
#                                  colsample_bytree=1, gamma=0, gpu_id=-1,
#                                  importance_type='gain',
#                                  interaction_constraints='',
#                                  learning_rate=0.300000012, max_delta_step=0,
#                                  max_depth=6, min_child_weight=1, missing=nan,
#                                  monotone_constraints='()', n_estimators=100,
#                                  n_jobs=-1, num_parallel_tree=1, random_state=123,
#                                  reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                  subsample=1, tree_method='exact',
#                                  validate_parameters=1, verbosity=None))]),
#   'cv_Recall_scores': array([0.88888889, 0.84126984, 0.76190476, 0.76190476, 0.68253968]),
#   'cv_Precision_scores': array([0.90322581, 0.96363636, 0.97959184, 0.85714286, 0.91489362]),
#   'cv_f1_scores': array([0.896     , 0.89830508, 0.85714286, 0.80672269, 0.78181818]),
#   'cvAvg_Recall_score': 0.7873015873015874,
#   'cvAvg_Precision_score': 0.9236980961973608,
#   'cvAvg_f1_score': 0.8479977625564864,
#   'fitted_model': XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                 importance_type='gain', interaction_constraints='',
#                 learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#                 random_state=123, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                 subsample=1, tree_method='exact', validate_parameters=1,
#                 verbosity=None),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.810126582278481,
#   'test_Precision_score': 0.927536231884058,
#   'test_f1_score': 0.8648648648648648,
#   'pred_prob': array([3.0137219e-06, 2.2788995e-06, 7.8175954e-06, ..., 6.1361816e-06,
#          6.9408168e-07, 4.9807909e-07], dtype=float32),
#   'cnf_matrix': array([[45485,     5],
#          [   15,    64]]),
#   'cs_cnf_matrix': array([[   0.  ,   30.5 ],
#          [1956.07,  310.  ]]),
#   'TotalCosts': 2296.5699999999997},
#  'LR': {'clf_desc': 'LogisticRegression',
#   'model': LogisticRegression(n_jobs=-1, random_state=123),
#   'c': 'r',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe585462950>,
#   'threshold': 0.5,
#   'pipeline': Pipeline(steps=[('Classifier',
#                    LogisticRegression(n_jobs=-1, random_state=123))]),
#   'cv_Recall_scores': array([0.79365079, 0.66666667, 0.53968254, 0.63492063, 0.50793651]),
#   'cv_Precision_scores': array([0.94339623, 0.875     , 0.85      , 0.83333333, 0.82051282]),
#   'cv_f1_scores': array([0.86206897, 0.75675676, 0.66019417, 0.72072072, 0.62745098]),
#   'cvAvg_Recall_score': 0.6285714285714286,
#   'cvAvg_Precision_score': 0.8644484760522497,
#   'cvAvg_f1_score': 0.7254383196288314,
#   'fitted_model': LogisticRegression(n_jobs=-1, random_state=123),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.6455696202531646,
#   'test_Precision_score': 0.9272727272727272,
#   'test_f1_score': 0.7611940298507464,
#   'pred_prob': array([1.25499902e-03, 2.24618298e-04, 7.16930653e-04, ...,
#          1.81020911e-03, 2.03276030e-04, 4.85609029e-05]),
#   'cnf_matrix': array([[45486,     4],
#          [   28,    51]]),
#   'cs_cnf_matrix': array([[   0.  ,   30.5 ],
#          [4149.56,  230.  ]]),
#   'TotalCosts': 4410.06},
#  'RF_smote': {'clf_desc': 'RandomForest',
#   'model': RandomForestClassifier(n_jobs=-1, random_state=123),
#   'c': 'g',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe5898ac950>,
#   'threshold': 0.5,
#   'SMOTE_bestparm': 0.04,
#   'pipeline': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.04)),
#                   ('Classifier',
#                    RandomForestClassifier(n_jobs=-1, random_state=123))]),
#   'fitted_model': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.04)),
#                   ('Classifier',
#                    RandomForestClassifier(n_jobs=-1, random_state=123))]),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.7974683544303798,
#   'test_Precision_score': 0.9,
#   'test_f1_score': 0.8456375838926175,
#   'pred_prob': array([0., 0., 0., ..., 0., 0., 0.]),
#   'cnf_matrix': array([[45483,     7],
#          [   16,    63]]),
#   'cs_cnf_matrix': array([[   0.   ,   35.495],
#          [2274.23 ,  310.   ]]),
#   'TotalCosts': 2619.7249999999995},
#  'XGB_smote': {'clf_desc': 'XGBoost',
#   'model': XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                 importance_type='gain', interaction_constraints='',
#                 learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#                 random_state=123, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                 subsample=1, tree_method='exact', validate_parameters=1,
#                 verbosity=None),
#   'c': 'blue',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe585426590>,
#   'threshold': 0.5,
#   'SMOTE_bestparm': 0.15,
#   'pipeline': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.15)),
#                   ('Classifier',
#                    XGBClassifier(base_score=0.5, booster='gbtree',
#                                  colsample_bylevel=1, colsample_bynode=1,
#                                  colsample_bytree=1, gamma=0, gpu_id=-1,
#                                  importance_type='gain',
#                                  interaction_constraints='',
#                                  learning_rate=0.300000012, max_delta_step=0,
#                                  max_depth=6, min_child_weight=1, missing=nan,
#                                  monotone_constraints='()', n_estimators=100,
#                                  n_jobs=-1, num_parallel_tree=1, random_state=123,
#                                  reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                  subsample=1, tree_method='exact',
#                                  validate_parameters=1, verbosity=None))]),
#   'fitted_model': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.15)),
#                   ('Classifier',
#                    XGBClassifier(base_score=0.5, booster='gbtree',
#                                  colsample_bylevel=1, colsample_bynode=1,
#                                  colsample_bytree=1, gamma=0, gpu_id=-1,
#                                  importance_type='gain',
#                                  interaction_constraints='',
#                                  learning_rate=0.300000012, max_delta_step=0,
#                                  max_depth=6, min_child_weight=1, missing=nan,
#                                  monotone_constraints='()', n_estimators=100,
#                                  n_jobs=-1, num_parallel_tree=1, random_state=123,
#                                  reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                  subsample=1, tree_method='exact',
#                                  validate_parameters=1, verbosity=None))]),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.8354430379746836,
#   'test_Precision_score': 0.88,
#   'test_f1_score': 0.8571428571428572,
#   'pred_prob': array([8.6202963e-05, 1.5591913e-06, 2.9249134e-06, ..., 1.5469838e-06,
#          4.6067068e-08, 5.4733340e-07], dtype=float32),
#   'cnf_matrix': array([[45481,     9],
#          [   13,    66]]),
#   'cs_cnf_matrix': array([[   0.   ,   35.995],
#          [1890.24 ,  320.   ]]),
#   'TotalCosts': 2246.235},
#  'LR_smote': {'clf_desc': 'LogisticRegression',
#   'model': LogisticRegression(n_jobs=-1, random_state=123),
#   'c': 'r',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe585462950>,
#   'threshold': 0.5,
#   'SMOTE_bestparm': 0.2,
#   'pipeline': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.2)),
#                   ('Classifier',
#                    LogisticRegression(n_jobs=-1, random_state=123))]),
#   'fitted_model': Pipeline(steps=[('scaler', StandardScaler()),
#                   ('SMOTE',
#                    SMOTE(n_jobs=-1, random_state=123, sampling_strategy=0.2)),
#                   ('Classifier',
#                    LogisticRegression(n_jobs=-1, random_state=123))]),
#   'y_pred': array([0, 0, 0, ..., 0, 0, 0]),
#   'test_Recall_score': 0.8734177215189873,
#   'test_Precision_score': 0.23469387755102042,
#   'test_f1_score': 0.3699731903485255,
#   'pred_prob': array([0.03186791, 0.00412029, 0.0681258 , ..., 0.02825278, 0.00495536,
#          0.00246086]),
#   'cnf_matrix': array([[45265,   225],
#          [   10,    69]]),
#   'cs_cnf_matrix': array([[   0.   ,  904.085],
#          [1822.82 ,  320.   ]]),
#   'TotalCosts': 3046.9049999999997},
#  'Voting': {'clf_desc': 'Voting Ensemble',
#   'model': VotingClassifier(estimators=[['LR_smote',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('SMOTE',
#                                                  SMOTE(n_jobs=-1,
#                                                        random_state=123,
#                                                        sampling_strategy=0.2)),
#                                                 ('Classifier',
#                                                  LogisticRegression(n_jobs=-1,
#                                                                     random_state=123))])],
#                                ['RF_smote',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('SMOTE',
#                                                  SMOTE(n_jobs=-1,
#                                                        random_state=123,
#                                                        sampling_strategy=0.04)),
#                                                 ('Classifie...
#                                                                importance_type='gain',
#                                                                interaction_constraints='',
#                                                                learning_rate=0.300000012,
#                                                                max_delta_step=0,
#                                                                max_depth=6,
#                                                                min_child_weight=1,
#                                                                missing=nan,
#                                                                monotone_constraints='()',
#                                                                n_estimators=100,
#                                                                n_jobs=-1,
#                                                                num_parallel_tree=1,
#                                                                random_state=123,
#                                                                reg_alpha=0,
#                                                                reg_lambda=1,
#                                                                scale_pos_weight=1,
#                                                                subsample=1,
#                                                                tree_method='exact',
#                                                                validate_parameters=1,
#                                                                verbosity=None))])]],
#                    voting='soft'),
#   'c': 'purple',
#   'cmap': <matplotlib.colors.LinearSegmentedColormap at 0x7fe5ad4f2a10>,
#   'threshold': 0.5,
#   'DecisionFunction': False,
#   'pipeline': Pipeline(steps=[['Voting',
#                    VotingClassifier(estimators=[['LR_smote',
#                                                  Pipeline(steps=[('scaler',
#                                                                   StandardScaler()),
#                                                                  ('SMOTE',
#                                                                   SMOTE(n_jobs=-1,
#                                                                         random_state=123,
#                                                                         sampling_strategy=0.2)),
#                                                                  ('Classifier',
#                                                                   LogisticRegression(n_jobs=-1,
#                                                                                      random_state=123))])],
#                                                 ['RF_smote',
#                                                  Pipeline(steps=[('scaler',
#                                                                   StandardScaler()),
#                                                                  ('SMOTE',
#                                                                   SMOTE(n_jobs=-1,
#                                                                         random_state=123,
#                                                                         sampling_s...
#                                                                                 importance_type='gain',
#                                                                                 interaction_constraints='',
#                                                                                 learning_rate=0.300000012,
#                                                                                 max_delta_step=0,
#                                                                                 max_depth=6,
#                                                                                 min_child_weight=1,
#                                                                                 missing=nan,
#                                                                                 monotone_constraints='()',
#                                                                                 n_estimators=100,
#                                                                                 n_jobs=-1,
#                                                                                 num_parallel_tree=1,
#                                                                                 random_state=123,
#                                                                                 reg_alpha=0,
#                                                                                 reg_lambda=1,
#                                                                                 scale_pos_weight=1,
#                                                                                 subsample=1,
#                                                                                 tree_method='exact',
#                                                                                 validate_parameters=1,
#                                                                                 verbosity=None))])]],
#                                     voting='soft')]])}}

# %%
clf_lst = ['RF_smote','XGB_smote','LR_smote', 'Voting']
# show the dollar costs for SMOTE upsampled model
cost_matrix = sc.partial_review(c_test, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_test, y_test, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_test, y_test)

# %%
# Try on holdout data
clf_lst = ['RF_smote','XGB_smote','LR_smote', 'Voting']
# show the dollar costs for SMOTE upsampled model
cost_matrix = sc.partial_review(c_holdout, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_holdout, y_holdout, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_holdout, y_holdout)

# %%
h.save_classifier_dict(classifiers, "22")

# %%
import numpy as np

# can try training on the entire non-holdout set
clf_lst = ['LR_smote','RF_smote','XGB_smote']

# # merge the test and train data for final project fit
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)
classifiers = sm.fit_classifiers(clf_lst, classifiers, X, y, SMOTE=True, TimeIt=True)
classifiers = sm.score_classifiers(clf_lst, classifiers, X_test, y_test)
# Out:
# 6 seconds fit execution time for LR_smote classifier
# 34 seconds fit execution time for RF_smote classifier
# 123 seconds fit execution time for XGB_smote classifier

# %%
# show the dollar costs for SMOTE upsampled model on final 
cost_matrix = sc.partial_review(c_holdout, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_holdout, y_holdout, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_holdout, y_holdout)

# %%
# add the ensemble
classifiers = sm.create_voting_classifier(clf_lst, classifiers, X, y)

# %%
clf_lst = ['RF_smote','XGB_smote','LR_smote', 'Voting']
# show the dollar costs for SMOTE upsampled model
cost_matrix = sc.partial_review(c_test, ReviewCost, ChargebackFee)
sc.class_probabilities(clf_lst, classifiers, X_test, y_test, cost_matrix=cost_matrix)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=False)
sc.plot_multiple_confusion_matrix(clf_lst, classifiers, CostSensitive=True)
fig, ax = plt.subplots()
sc.plot_total_cost(ax, clf_lst, classifiers, c_test, y_test)

# %%
might have to create and train the voting classifier separately to fix error above

# %% [markdown]
# to do
# - add cost matrix diagram
# - add pca plot
# - add recall-precision plot
# - add thesholding - maybe? - YES!!!!!
# - tune the random forest **
# - study up on the XGB
# - wont get to this but could do an isolation forest
